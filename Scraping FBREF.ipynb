# %%
pip install --upgrade LanusStats
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.4/79.4 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import LanusStats as ls

# %%
ls.get_available_pages()
# Out:
# dict_keys(['Fbref', 'Sofascore', '365Scores', 'Fotmob'])

# %%
ls.get_available_leagues('Fbref')
# Out:
# ['Copa de la Liga',
#  'Primera Division Argentina',
#  'Primera Division Uruguay',
#  'Brasileirao',
#  'Brasileirao B',
#  'Primera Division Colombia',
#  'Primera Division Chile',
#  'Primera Division Peru',
#  'Primera Division Venezuela',
#  'Primera Division Ecuador',
#  'Primera Division Bolivia',
#  'Primera Division Paraguay',
#  'Brasileirao F',
#  'MLS',
#  'USL Championship',
#  'Premier League',
#  'La Liga',
#  'Ligue 1',
#  'Bundesliga',
#  'Serie A',
#  'Big 5 European Leagues',
#  'Danish Superliga',
#  'Eredivise',
#  'Primeira Liga Portugal']

# %%
ls.get_available_season_for_leagues('Fbref','Premier League')
# Out:
# {'id': 9,
#  'slug': 'Premier-League',
#  'seasons': {'2020-2021', '2021-2022', '2022-2023', '2023-2024'}}

# %%
Fbref= ls.Fbref()

# %%
Fbref.possible_stats
# Out:
# ['stats',
#  'keepers',
#  'keepersadv',
#  'shooting',
#  'passing',
#  'passing_types',
#  'gca',
#  'defense',
#  'possession',
#  'playingtime',
#  'misc']

# %%
Fbref.get_teams_season_stats('stats', 'Premier League','2023-2024', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#               Squad  # Pl   Age  Poss  PlayingTime_MP  PlayingTime_Starts  \
# 0           Arsenal    25  25.0  58.2              38                 418
# 1       Aston Villa    31  26.9  53.1              38                 418
# 2       Bournemouth    30  25.7  44.4              38                 418
# 3         Brentford    28  26.6  45.2              38                 418
# 4          Brighton    30  25.9  59.8              38                 418
# 5           Burnley    31  24.5  47.4              38                 418
# 6           Chelsea    32  24.2  58.6              38                 418
# 7    Crystal Palace    26  26.7  42.3              38                 418
# 8           Everton    26  27.1  40.8              38                 418
# 9            Fulham    25  28.4  50.6              38                 418
# 10        Liverpool    30  26.3  61.3              38                 418
# ...

# %%
Fbref.get_teams_season_stats('keepers', 'Serie A','2021-2022', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl  PlayingTime_MP  PlayingTime_Starts  PlayingTime_Min  \
# 0        Atalanta     3              38                  38             3419
# 1         Bologna     3              38                  38             3420
# 2        Cagliari     2              38                  38             3420
# 3          Empoli     1              38                  38             3420
# 4      Fiorentina     2              38                  38             3418
# 5           Genoa     2              38                  38             3420
# 6   Hellas Verona     3              38                  38             3420
# 7           Inter     2              38                  38             3420
# 8        Juventus     3              38                  38             3420
# 9           Lazio     2              38                  38             3420
# 10          Milan     2              38                  38             3420
# ...

# %%
Fbref.get_teams_season_stats('keepersadv', 'Serie A','2021-2022', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   90s  Goals_GA  Goals_PKA  Goals_FK  Goals_CK  \
# 0        Atalanta     3  38.0        48          5         0         3
# 1         Bologna     3  38.0        55          8         1         3
# 2        Cagliari     2  38.0        68          7         5        10
# 3          Empoli     1  38.0        70          5         1         5
# 4      Fiorentina     2  38.0        51          3         0         3
# 5           Genoa     2  38.0        60          4         3         7
# 6   Hellas Verona     3  38.0        59          3         2         8
# 7           Inter     2  38.0        32          4         0         3
# 8        Juventus     3  38.0        37          4         2         6
# 9           Lazio     2  38.0        58          5         1         5
# 10          Milan     2  38.0        31          4         0         5
# 11         Napoli     3  38.0        31          1         0         3
# ...

# %%
Fbref.get_teams_season_stats('shooting', 'Serie A','2021-2022', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   90s  Standard_Gls  Standard_Sh  Standard_SoT  \
# 0        Atalanta    32  38.0            62          598           167
# 1         Bologna    36  38.0            43          434           143
# 2        Cagliari    33  38.0            34          420           117
# 3          Empoli    28  38.0            47          490           151
# 4      Fiorentina    28  38.0            59          501           172
# 5           Genoa    40  38.0            26          397           106
# 6   Hellas Verona    31  38.0            63          455           152
# 7           Inter    27  38.0            83          667           239
# 8        Juventus    32  38.0            56          517           166
# 9           Lazio    27  38.0            74          445           185
# 10          Milan    28  38.0            66          592           187
# 11         Napoli    27  38.0            74          565           186
# ...

# %%
Fbref.get_teams_season_stats('passing', 'Serie A','2021-2022', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   90s  Total_Cmp  Total_Att  Total_Cmp%  \
# 0        Atalanta    32  38.0      17108      21261        80.5
# 1         Bologna    36  38.0      14442      18249        79.1
# 2        Cagliari    33  38.0      11503      15761        73.0
# 3          Empoli    28  38.0      12796      16700        76.6
# 4      Fiorentina    28  38.0      17418      20910        83.3
# 5           Genoa    40  38.0      11185      15587        71.8
# 6   Hellas Verona    31  38.0      13047      17398        75.0
# 7           Inter    27  38.0      18367      21832        84.1
# 8        Juventus    32  38.0      16459      19835        83.0
# 9           Lazio    27  38.0      19632      23041        85.2
# 10          Milan    28  38.0      15719      19320        81.4
# 11         Napoli    27  38.0      19572      22921        85.4
# 12           Roma    29  38.0      15221      18828        80.8
# ...

# %%
Fbref.get_teams_season_stats('passing_types', 'Serie A','2021-2022', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   90s    Att  PassTypes_Live  PassTypes_Dead  \
# 0        Atalanta    32  38.0  21261           19317            1876
# 1         Bologna    36  38.0  18249           16283            1910
# 2        Cagliari    33  38.0  15761           13729            1962
# 3          Empoli    28  38.0  16700           14627            1990
# 4      Fiorentina    28  38.0  20910           19005            1848
# 5           Genoa    40  38.0  15587           13605            1910
# 6   Hellas Verona    31  38.0  17398           15513            1788
# 7           Inter    27  38.0  21832           20151            1624
# 8        Juventus    32  38.0  19835           18065            1696
# 9           Lazio    27  38.0  23041           21310            1687
# 10          Milan    28  38.0  19320           17512            1728
# 11         Napoli    27  38.0  22921           21114            1740
# ...

# %%
Fbref.get_teams_season_stats('gca', 'Serie A','2021-2022', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   90s  SCA_SCA  SCA_SCA90  SCATypes_PassLive  \
# 0        Atalanta    32  38.0     1078      28.37                776
# 1         Bologna    36  38.0      777      20.45                599
# 2        Cagliari    33  38.0      742      19.53                521
# 3          Empoli    28  38.0      835      21.97                622
# 4      Fiorentina    28  38.0      908      23.89                655
# 5           Genoa    40  38.0      684      18.00                462
# 6   Hellas Verona    31  38.0      796      20.95                607
# 7           Inter    27  38.0     1184      31.16                885
# 8        Juventus    32  38.0      917      24.13                677
# 9           Lazio    27  38.0      798      21.00                610
# 10          Milan    28  38.0     1026      27.00                717
# 11         Napoli    27  38.0     1021      26.87                778
# ...

# %%
Fbref.get_teams_season_stats('defense', 'Serie A','2021-2022', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   90s  Tackles_Tkl  Tackles_TklW  Tackles_Def3rd  \
# 0        Atalanta    32  38.0          630           341             252
# 1         Bologna    36  38.0          530           298             261
# 2        Cagliari    33  38.0          557           303             263
# 3          Empoli    28  38.0          568           327             268
# 4      Fiorentina    28  38.0          508           301             232
# 5           Genoa    40  38.0          739           416             324
# 6   Hellas Verona    31  38.0          534           308             248
# 7           Inter    27  38.0          588           332             265
# 8        Juventus    32  38.0          555           316             260
# 9           Lazio    27  38.0          578           339             246
# 10          Milan    28  38.0          697           421             304
# ...

# %%
Fbref.get_teams_season_stats('possession', 'Serie A','2021-2022', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl  Poss   90s  Touches_Touches  Touches_DefPen  \
# 0        Atalanta    32  55.0  38.0            25624            1875
# 1         Bologna    36  50.6  38.0            22181            2573
# 2        Cagliari    33  44.5  38.0            19878            2390
# 3          Empoli    28  47.4  38.0            20894            2792
# 4      Fiorentina    28  57.7  38.0            24439            2417
# 5           Genoa    40  43.9  38.0            20229            2408
# 6   Hellas Verona    31  50.6  38.0            21791            2173
# 7           Inter    27  56.5  38.0            25692            2568
# 8        Juventus    32  51.5  38.0            23918            2492
# 9           Lazio    27  55.4  38.0            26867            2495
# 10          Milan    28  54.0  38.0            23507            2057
# 11         Napoli    27  58.3  38.0            26604            2258
# ...

# %%
Fbref.get_teams_season_stats('playingtime', 'Serie A','2021-2022', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   Age  PlayingTime_MP  PlayingTime_Min  \
# 0        Atalanta    32  27.5              38             3420
# 1         Bologna    36  26.6              38             3420
# 2        Cagliari    33  26.5              38             3420
# 3          Empoli    28  24.5              38             3420
# 4      Fiorentina    28  26.4              38             3420
# 5           Genoa    40  27.0              38             3420
# 6   Hellas Verona    31  26.8              38             3420
# 7           Inter    27  28.9              38             3420
# 8        Juventus    32  27.4              38             3420
# 9           Lazio    27  29.0              38             3420
# 10          Milan    28  25.6              38             3420
# 11         Napoli    27  27.9              38             3420
# 12           Roma    29  26.4              38             3420
# ...

# %%
Fbref.get_teams_season_stats('misc', 'Serie A','2021-2022', change_columns_names=True)
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   90s  Performance_CrdY  Performance_CrdR  \
# 0        Atalanta    32  38.0                87                 2
# 1         Bologna    36  38.0                92                 7
# 2        Cagliari    33  38.0                96                 5
# 3          Empoli    28  38.0                87                 5
# 4      Fiorentina    28  38.0                89                 8
# 5           Genoa    40  38.0                92                 3
# 6   Hellas Verona    31  38.0               100                 7
# 7           Inter    27  38.0                71                 0
# 8        Juventus    32  38.0                77                 2
# 9           Lazio    27  38.0                88                 5
# 10          Milan    28  38.0                76                 3
# 11         Napoli    27  38.0                63                 2
# ...

# %%
pip install pandas openpyxl

# %%
import pandas as pd
import os

# Lista de nombres de tablas
table_names = ['stats', 'keepers', 'keepersadv', 'shooting','passing','passing_types', 'gca', 'defense', 'possession', 'playingtime', 'misc']

# Diccionario para almacenar los DataFrames
dataframes = {}

# Suponiendo que usas fbref.get_player_season_stats para obtener los DataFrames
# Cargar las tablas en el diccionario
for table_name in table_names:
    dataframes[table_name] = Fbref.get_teams_season_stats(table_name, 'Serie A', '2021-2022')

# Definir el nombre del archivo Excel
file_path = 'Serie A_Equipos.xlsx'

# Escribir los DataFrames a un archivo Excel con diferentes hojas
with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
    for sheet_name, dataframe in dataframes.items():
        dataframe.to_excel(writer, sheet_name=sheet_name, index=False)

print("Archivo Excel guardado con éxito.")
# Out:
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Archivo Excel guardado con éxito.

# %%
Fbref.get_player_percentiles('https://fbref.com/es/jugadores/20730eae/Rafael-Leao')
# Out:
#                                       Estadísticas Por 90  Percentil
# 0                           Goles sin penalización   0.36       85.0
# 1   npxG: Goles esperados (xG) sin contar penaltis   0.36       90.0
# 2                                Total de disparos   2.62       74.0
# 3                                      Asistencias   0.33       86.0
# 4                    xAG: Exp. Objetivos asistidos   0.30       88.0
# 5                                       npxG + xAG   0.66       95.0
# 6               Acciones para la creación de tiros   4.48       72.0
# 7                                              NaN    NaN        NaN
# 8                                 Pases intentados  34.43       37.0
# 9                               % de pase completo  73.6%       36.0
# 10                               Pases progresivos   3.62       46.0
# 11                            Acarreos progresivos   5.37       87.0
# 12                                  Tomas exitosas   2.78       85.0
# ...

# %%
ls.visualizations.fbref_plot_player_percentiles('https://fbref.com/es/jugadores/20730eae/Rafael-Leao', name_extra= ' AC Milan', credit_extra= 'Hecho con video',chart_stats = ['Ataque','Pases', 'Defensa'])
# Out:
# Gettings player percentiles...
# Starting to plot...

# %%
Fbref.get_player_similarities('https://fbref.com/es/jugadores/20730eae/Rafael-Leao')
# Out:
#    RL                Jugador     País         Equipo  Comparar
# 0   1        Raheem Sterling  eng ENG        Chelsea  Comparar
# 1   2              Luis Díaz   co COL      Liverpool  Comparar
# 2   3             Leroy Sané   de GER  Bayern Munich  Comparar
# 3   4            Bukayo Saka  eng ENG        Arsenal  Comparar
# 4   5             João Félix   pt POR      Barcelona  Comparar
# 5   6          Edon Zhegrova   xk KVX          Lille  Comparar
# 6   7               Raphinha   br BRA      Barcelona  Comparar
# 7   8     Gabriel Martinelli   br BRA        Arsenal  Comparar
# 8   9         Kingsley Coman   fr FRA  Bayern Munich  Comparar
# 9  10  Khvicha Kvaratskhelia   ge GEO         Napoli  Comparar

# %%
Fbref.get_match_shots('https://fbref.com/es/partidos/833bac38/Cagliari-Fiorentina-Mayo-23-2024-Serie-A')
# Out:
#    Minute                Jugador      Equipo    xG  PSxG         Resultado  \
# 0       8      Gianluca Lapadula    Cagliari  0.06   NaN  Fuera del blanco
# 1      16          Nicolas Viola    Cagliari  0.05   NaN  Fuera del blanco
# 2      20         Andrea Belotti  Fiorentina  0.08  0.06           Salvado
# 3      24         Andrea Belotti  Fiorentina  0.12   NaN         Bloqueado
# 4      25          Antonín Barák  Fiorentina  0.06   NaN  Fuera del blanco
# 5      26                   Dodô  Fiorentina  0.02   NaN         Bloqueado
# 6      27      Alessandro Deiola    Cagliari  0.35   NaN  Fuera del blanco
# 7      28           Zito Luvumbo    Cagliari  0.12  0.36           Salvado
# 8      29      Alessandro Deiola    Cagliari  0.08  0.22           Salvado
# 9      33           Zito Luvumbo    Cagliari  0.25  0.30           Salvado
# 10     34           Matteo Prati    Cagliari  0.07   NaN         Travesaño
# ...

# %%
Fbref.get_general_match_team_stats('https://fbref.com/es/partidos/833bac38/Cagliari-Fiorentina-Mayo-23-2024-Serie-A')[0]
# Out:
#      Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Jugador               núm.               País
# 0     Gianluca Lapadula                9.0             pe PER
# 1          Zito Luvumbo               77.0             ao ANG
# 2    Kingstone Mutandwa               34.0             zm ZAM
# 3        Nahitan Nández                8.0             uy URU
# 4   Alessandro Di Pardo               99.0             it ITA
# 5         Nicolas Viola               10.0             it ITA
# 6     Alessandro Deiola               14.0             it ITA
# 7      Ibrahim Sulemana               25.0             gh GHA
# 8         Marco Mancosu                5.0             it ITA
# 9          Matteo Prati               16.0             it ITA
# 10      Tommaso Augello               27.0             it ITA
# 11           Adam Obert               33.0             sk SVK
# 12           Yerry Mina               26.0             co COL
# ...

# %%
Fbref.get_teams_season_stats('stats', 'Premier League','2023-2024', change_columns_names=True)

# %%
# A partir de aquí no es para bajar datos en xlsx sino en csv
import pandas as pd
import os

# Lista de nombres de tablas
table_names = ['stats']
# , 'keepers', 'keepersadv', 'shooting','passing','passing_types', 'gca', 'defense', 'possession', 'playingtime', 'misc']

# Diccionario para almacenar los DataFrames
dataframes = {}

# Suponiendo que usas fbref.get_player_season_stats para obtener los DataFrames
# Cargar las tablas en el diccionario
for table_name in table_names:
    dataframes[table_name] = Fbref.get_player_season_stats(table_name, 'Premier League', '2023-2024')

# Definir la ruta del directorio donde se guardarán los archivos CSV
directory = 'StatsPremierLeague'

# Crear el directorio si no existe
if not os.path.exists(directory):
    os.makedirs(directory)

# Escribir los DataFrames a archivos CSV
for table_name, dataframe in dataframes.items():
    file_path = os.path.join(directory, f'{table_name}.csv')
    dataframe.to_csv(file_path, index=False)

print("Archivos CSV guardados con éxito.")
# Out:
# Starting to scrape player data from Fbref...
# Archivos CSV guardados con éxito.

# %%
import pandas as pd

# Ruta del archivo CSV (asegúrate de que es correcta)
file_path = '/content/stats.csv'

# Leer el archivo CSV
df = pd.read_csv(file_path)

# Mostrar las primeras filas del DataFrame
print(df.head())
