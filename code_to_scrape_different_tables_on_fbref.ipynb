# %% [markdown]
# <a href="https://colab.research.google.com/github/Torressk/TFM-EU/blob/main/code_to_scrape_different_tables_on_fbref.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Code to scrape different tables on fbref

# %%
import pandas as pd

# %%
#add url and table id
df = pd.read_html ('https://fbref.com/en/comps/Big5/stats/squads/Big-5-European-Leagues-Stats',
                   attrs={"id":"stats_teams_standard_for"})[0]

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0  Unnamed: 2_level_0  \
#                   Rk              Squad                Comp
# 0                  1             Alavés          es La Liga
# 1                  2            Almería          es La Liga
# 2                  3            Arsenal  eng Premier League
# 3                  4        Aston Villa  eng Premier League
# 4                  5           Atalanta          it Serie A
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0 Playing Time  \
#                 # Pl                Age               Poss           MP
# 0                 30               25.6               41.8           38
# 1                 35               25.6               46.4           38
# 2                 25               25.0               58.2           38
# 3                 31               26.9               53.1           38
# 4                 29               26.3               51.1           38
#
# ...

# %%
#to join table names if necessary
df.columns = ['_'.join(col).strip() for col in df.columns.values]

# %%
df.head()
# Out:
#    Unnamed: 0_level_0_Rk Unnamed: 1_level_0_Squad Unnamed: 2_level_0_Comp  \
# 0                      1                   Alavés              es La Liga
# 1                      2                  Almería              es La Liga
# 2                      3                  Arsenal      eng Premier League
# 3                      4              Aston Villa      eng Premier League
# 4                      5                 Atalanta              it Serie A
#
#    Unnamed: 3_level_0_# Pl  Unnamed: 4_level_0_Age  Unnamed: 5_level_0_Poss  \
# 0                       30                    25.6                     41.8
# 1                       35                    25.6                     46.4
# 2                       25                    25.0                     58.2
# 3                       31                    26.9                     53.1
# 4                       29                    26.3                     51.1
#
# ...
